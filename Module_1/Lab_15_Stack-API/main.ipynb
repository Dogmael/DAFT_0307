# %% [markdown]
# # Ressources :
#
# https://stackapi.readthedocs.io/en/latest/user/advanced.html#advanced
#
# https://api.stackexchange.com/docs/types/filter
#
# https://api.stackexchange.com/docs/answers-on-questions
#
# https://stackoverflow.com/questions/65687547/how-can-i-use-custom-filters-in-the-stack-exchange-api

# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import datetime

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI('stackoverflow')

start_date = datetime.datetime(2023 , 6, 11)
end_date = datetime.datetime(2023 , 7, 11)


questions = SITE.fetch('questions', fromdate=start_date, todate=end_date)

# %%
answers = SITE.fetch('answers', fromdate=start_date, todate=end_date)

# %%
answers["items"]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions = SITE.fetch('questions', fromdate=start_date, todate=start_date, tagged='python')

questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 117,
#  'total': 0,
#  'items': []}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers_6784_6473 = SITE.fetch("questions", filter="!nNPvSNXQuR")
answers_6784_6473
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 46,
#  'total': 0,
#  'items': [{'tags': ['pandas', 'categorical'],
#    'owner': {'reputation': 1,
#     'user_id': 22084118,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/WYLSX.jpg?s=256&g=1',
#     'display_name': 'E.L',
#     'link': 'https://stackoverflow.com/users/22084118/e-l'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1689080825,
#    'creation_date': 1689080598,
#    'last_edit_date': 1689080825,
#    'question_id': 76662280,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76662280/i-dont-understand-groupby-behavior-in-pandas-with-categorical-data',
#    'title': 'I don&#39;t understand groupby behavior in Pandas with categorical data'},
#   {'tags': ['php', 'node.js'],
#    'owner': {'reputation': 22,
#     'user_id': 21350485,
# ...
